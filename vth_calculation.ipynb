# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

path1 = 'I_V Sweep - Unit (transfer) [251203_ALD_#1_R09(12) ; 1_16_2026 11_02_37 AM].csv'
path2 = 'I_V Sweep - Unit (transfer) [251203_ALD_#2_R01(2) ; 1_16_2026 10_23_57 AM].csv'
path3 = 'I_V Sweep - Unit (transfer) [251203_ALD_#3_R00(3) ; 1_16_2026 10_29_12 AM].csv'
path4 = 'I_V Sweep - Unit (transfer) [251203_ALD_#4_R00(4) ; 1_16_2026 10_33_07 AM].csv'
path5 = 'I_V Sweep - Unit (transfer) [251203_ALD_#5_R00(5) ; 1_16_2026 10_37_16 AM].csv'
path6 = 'I_V Sweep - Unit (transfer) [251203_ALD_#6_R00(6) ; 1_16_2026 10_40_38 AM].csv'
path7 = 'I_V Sweep - Unit (transfer) [251203_ALD_#7_R00(7) ; 1_16_2026 10_44_34 AM].csv'
path8 = 'I_V Sweep - Unit (transfer) [251203_ALD_#8_R00(9) ; 1_16_2026 10_51_19 AM].csv'
path9 = 'I_V Sweep - Unit (transfer) [251203_ALD_#9_R00(10) ; 1_16_2026 10_55_26 AM].csv'

paths = [path1, path2, path3, path4, path5, path6, path7, path8, path9]
dfs = []

for i in range(len(paths)):
    with open(paths[i], 'r', encoding = 'utf-8') as f:
        lines = f.readlines()
        for j, line in enumerate(lines):
            if line.startswith('DataValue')== True:
                skiprow_n = j - 1
                break
    df = pd.read_csv(paths[i], sep = ',', skiprows = skiprow_n)
    dfs.append(df)

# %%
print(dfs[2])
# Out:
#       DataName    VG   VD   VS            IG            ID            IS  \
# 0    DataValue -3.00  0.1    0 -1.480000e-13  1.200000e-14 -4.500000e-14
# 1    DataValue -2.94  0.1    0 -7.200000e-14 -3.100000e-14  1.200000e-14
# 2    DataValue -2.88  0.1    0 -2.900000e-14 -4.300000e-14 -1.500000e-14
# 3    DataValue -2.82  0.1    0 -5.900000e-14 -2.900000e-14 -7.700000e-14
# 4    DataValue -2.76  0.1    0 -3.300000e-14 -2.200000e-14 -4.000000e-14
# ..         ...   ...  ...  ...           ...           ...           ...
# 500  DataValue  2.76  2.9    0 -5.600000e-14  3.666190e-05 -3.666120e-05
# 501  DataValue  2.82  2.9    0 -4.200000e-14  3.861200e-05 -3.861150e-05
# 502  DataValue  2.88  2.9    0 -7.300000e-14  4.061580e-05 -4.061370e-05
# 503  DataValue  2.94  2.9    0 -4.300000e-14  4.266660e-05 -4.266610e-05
# 504  DataValue  3.00  2.9    0 -4.000000e-14  4.476810e-05 -4.476570e-05
#
#                        SS
# 0      63.219080512239927
# 1        94.0222630653815
# ...
