# %%
import pandas as pd

df = pd.read_csv('datasets/German_credit/German_credit.csv', sep= ',')
column_name = df.columns

for i in column_name:
    check = df[i].isna().sum()
    print(f'{i} column의 결측값은 {check}개 입니다.')
# Out:
# Age column의 결측값은 0개 입니다.
# Sex column의 결측값은 0개 입니다.
# Job column의 결측값은 0개 입니다.
# Housing column의 결측값은 0개 입니다.
# Saving accounts column의 결측값은 183개 입니다.
# Checking account column의 결측값은 394개 입니다.
# Credit amount column의 결측값은 0개 입니다.
# Duration column의 결측값은 0개 입니다.
# Purpose column의 결측값은 0개 입니다.

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account',
#        'Credit amount', 'Duration', 'Purpose'],
#       dtype='object')

# %%
df['Age'].describe()
# Out:
# count    1000.000000
# mean       35.546000
# std        11.375469
# min        19.000000
# 25%        27.000000
# 50%        33.000000
# 75%        42.000000
# max        75.000000
# Name: Age, dtype: float64

# %%
pd.cut(df['Age'],bins = 8)
# Out:
# 0        (61.0, 68.0]
# 1      (18.944, 26.0]
# 2        (47.0, 54.0]
# 3        (40.0, 47.0]
# 4        (47.0, 54.0]
#             ...
# 995      (26.0, 33.0]
# 996      (33.0, 40.0]
# 997      (33.0, 40.0]
# 998    (18.944, 26.0]
# 999      (26.0, 33.0]
# Name: Age, Length: 1000, dtype: category
# Categories (8, interval[float64, right]): [(18.944, 26.0] < (26.0, 33.0] < (33.0, 40.0] < (40.0, 47.0] < (47.0, 54.0] < (54.0, 61.0] < (61.0, 68.0] < (68.0, 75.0]]

# %%
pd.cut(df['Age'],bins = 8).reset_index().groupby('Age').size()
# Out:
# Age
# (18.944, 26.0]    240
# (26.0, 33.0]      276
# (33.0, 40.0]      210
# (40.0, 47.0]      123
# (47.0, 54.0]       72
# (54.0, 61.0]       41
# (61.0, 68.0]       31
# (68.0, 75.0]        7
# dtype: int64
