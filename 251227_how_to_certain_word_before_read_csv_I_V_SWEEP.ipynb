# %%
import pandas as pd

path = 'I_V List Sweep - Step Marking (ISRC) [IGZO_ALD_#1_2T0C_LIST_SWEEP_R2C1_VD_PGM_CONST(3) ; 12_24_2025 2_35_27 PM].csv'

with open(path, 'r', encoding='utf-8') as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if any(col.strip().startswith('DataValue') for col in line.split(',')):
        header_row = i - 2   # 한 줄 위
        break
df = pd.read_csv(path, sep = ',', header = header_row)

df = df.iloc[:,1:]
# Out:
#            VG_PGM   VD_PGM       VD_READ   VS_READ        time        ID_PGM  \
# count  200.000000    200.0  2.000000e+02     200.0  200.000000  2.000000e+02
# mean    -1.900000      1.5  1.000000e-01       0.0   90.915752 -1.237500e-14
# std      0.626067      0.0  6.956306e-17       0.0   52.787538  2.582847e-14
# min     -2.000000      1.5  1.000000e-01       0.0    0.094280 -7.000000e-14
# 25%     -2.000000      1.5  1.000000e-01       0.0   45.544553 -3.125000e-14
# 50%     -2.000000      1.5  1.000000e-01       0.0   90.917410 -1.600000e-14
# 75%     -2.000000      1.5  1.000000e-01       0.0  136.288760  9.000000e-15
# max      2.000000      1.5  1.000000e-01       0.0  181.660730  8.700000e-14
#
#              IG_PGM       ID_READ       IS_READ
# count  2.000000e+02  2.000000e+02  2.000000e+02
# mean  -1.045000e-14  8.721625e-07 -8.720372e-07
# std    1.904603e-14  7.911942e-08  7.908769e-08
# min   -5.500000e-14  8.229700e-07 -1.341520e-06
# ...
